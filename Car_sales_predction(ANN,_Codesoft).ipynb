# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalyani2010/CodSoft_Internship/blob/main/Car_sales_predction(ANN%2C_Codesoft).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# Data Preprocessing

# %%
df = pd.read_csv('/content/sales_task4.csv', encoding='ISO-8859-1')

# Check the first few rows of the dataset
print(df.head())
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %% [markdown]
# Drop unneeded columns

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %% [markdown]
# Define X and y

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %% [markdown]
# Data Scaling

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %% [markdown]
# Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 4)
# (400, 1)
# (100, 4)
# (100, 1)

# %% [markdown]
# Modal Structure

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Modal Training

# %%
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 27ms/step - loss: 0.1786 - mean_absolute_error: 0.3921 - val_loss: 0.1609 - val_mean_absolute_error: 0.3627
# Epoch 2/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1192 - mean_absolute_error: 0.3099 - val_loss: 0.1025 - val_mean_absolute_error: 0.2749
# Epoch 3/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0695 - mean_absolute_error: 0.2223 - val_loss: 0.0560 - val_mean_absolute_error: 0.1937
# Epoch 4/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0351 - mean_absolute_error: 0.1506 - val_loss: 0.0294 - val_mean_absolute_error: 0.1430
# Epoch 5/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0209 - mean_absolute_error: 0.1118 - val_loss: 0.0227 - val_mean_absolute_error: 0.1208
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0200 - mean_absolute_error: 0.1092 - val_loss: 0.0211 - val_mean_absolute_error: 0.1153
# Epoch 7/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0177 - mean_absolute_error: 0.1013 - val_loss: 0.0190 - val_mean_absolute_error: 0.1104
# Epoch 8/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0156 - mean_absolute_error: 0.0952 - val_loss: 0.0177 - val_mean_absolute_error: 0.1075
# Epoch 9/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - mean_absolute_error: 0.0914 - val_loss: 0.0163 - val_mean_absolute_error: 0.1024
# Epoch 10/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0131 - mean_absolute_error: 0.0868 - val_loss: 0.0146 - val_mean_absolute_error: 0.0977
# Epoch 11/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0123 - mean_absolute_error: 0.0842 - val_loss: 0.0136 - val_mean_absolute_error: 0.0946
# Epoch 12/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0116 - mean_absolute_error: 0.0816 - val_loss: 0.0128 - val_mean_absolute_error: 0.0920
# Epoch 13/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0110 - mean_absolute_error: 0.0798 - val_loss: 0.0123 - val_mean_absolute_error: 0.0898
# Epoch 14/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0105 - mean_absolute_error: 0.0784 - val_loss: 0.0118 - val_mean_absolute_error: 0.0880
# Epoch 15/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0101 - mean_absolute_error: 0.0770 - val_loss: 0.0113 - val_mean_absolute_error: 0.0861
# Epoch 16/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0097 - mean_absolute_error: 0.0757 - val_loss: 0.0109 - val_mean_absolute_error: 0.0841
# Epoch 17/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0093 - mean_absolute_error: 0.0739 - val_loss: 0.0103 - val_mean_absolute_error: 0.0821
# Epoch 18/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - mean_absolute_error: 0.0723 - val_loss: 0.0099 - val_mean_absolute_error: 0.0798
# Epoch 19/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0084 - mean_absolute_error: 0.0707 - val_loss: 0.0094 - val_mean_absolute_error: 0.0778
# Epoch 20/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0080 - mean_absolute_error: 0.0690 - val_loss: 0.0089 - val_mean_absolute_error: 0.0758
# Epoch 21/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0076 - mean_absolute_error: 0.0676 - val_loss: 0.0084 - val_mean_absolute_error: 0.0737
# Epoch 22/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_absolute_error: 0.0656 - val_loss: 0.0081 - val_mean_absolute_error: 0.0720
# Epoch 23/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0069 - mean_absolute_error: 0.0641 - val_loss: 0.0077 - val_mean_absolute_error: 0.0702
# Epoch 24/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0626 - val_loss: 0.0073 - val_mean_absolute_error: 0.0681
# Epoch 25/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0617 - val_loss: 0.0070 - val_mean_absolute_error: 0.0665
# Epoch 26/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_absolute_error: 0.0597 - val_loss: 0.0068 - val_mean_absolute_error: 0.0655
# Epoch 27/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_absolute_error: 0.0582 - val_loss: 0.0064 - val_mean_absolute_error: 0.0631
# Epoch 28/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_absolute_error: 0.0570 - val_loss: 0.0061 - val_mean_absolute_error: 0.0619
# Epoch 29/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0051 - mean_absolute_error: 0.0553 - val_loss: 0.0058 - val_mean_absolute_error: 0.0597
# Epoch 30/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0049 - mean_absolute_error: 0.0536 - val_loss: 0.0055 - val_mean_absolute_error: 0.0584
# Epoch 31/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_absolute_error: 0.0522 - val_loss: 0.0052 - val_mean_absolute_error: 0.0565
# Epoch 32/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_absolute_error: 0.0509 - val_loss: 0.0050 - val_mean_absolute_error: 0.0556
# Epoch 33/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0041 - mean_absolute_error: 0.0492 - val_loss: 0.0047 - val_mean_absolute_error: 0.0538
# Epoch 34/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_absolute_error: 0.0480 - val_loss: 0.0044 - val_mean_absolute_error: 0.0519
# Epoch 35/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0037 - mean_absolute_error: 0.0465 - val_loss: 0.0042 - val_mean_absolute_error: 0.0508
# Epoch 36/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0035 - mean_absolute_error: 0.0452 - val_loss: 0.0040 - val_mean_absolute_error: 0.0493
# Epoch 37/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_absolute_error: 0.0441 - val_loss: 0.0037 - val_mean_absolute_error: 0.0474
# Epoch 38/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0031 - mean_absolute_error: 0.0427 - val_loss: 0.0035 - val_mean_absolute_error: 0.0463
# Epoch 39/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0410 - val_loss: 0.0033 - val_mean_absolute_error: 0.0446
# Epoch 40/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0401 - val_loss: 0.0031 - val_mean_absolute_error: 0.0434
# Epoch 41/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0026 - mean_absolute_error: 0.0389 - val_loss: 0.0030 - val_mean_absolute_error: 0.0423
# Epoch 42/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0368 - val_loss: 0.0027 - val_mean_absolute_error: 0.0403
# Epoch 43/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0357 - val_loss: 0.0026 - val_mean_absolute_error: 0.0392
# Epoch 44/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0024 - val_mean_absolute_error: 0.0375
# Epoch 45/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0330 - val_loss: 0.0023 - val_mean_absolute_error: 0.0363
# Epoch 46/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0318 - val_loss: 0.0021 - val_mean_absolute_error: 0.0349
# Epoch 47/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0307 - val_loss: 0.0020 - val_mean_absolute_error: 0.0337
# Epoch 48/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0295 - val_loss: 0.0018 - val_mean_absolute_error: 0.0325
# Epoch 49/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 0.0017 - val_mean_absolute_error: 0.0311
# Epoch 50/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - val_loss: 0.0016 - val_mean_absolute_error: 0.0301

# %% [markdown]
# independent and dependent variables

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.9525295804742265
